# %% [markdown]
# <a href="https://colab.research.google.com/github/diarrabell/space-images/blob/main/notebooks/space.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Connect to needed files from GitHub and Google Drive

# %%
import os
import getpass

#remove Colab default sample_data
# !rm -r ./sample_data
#clone github files to colab workspace
git_user = "diarrabell"
git_email = "diarrayb@gmail.com"
repo_name = "space-images"
# git_token = getpass.getpass("enter git token")
# git_path = f"https://{git_token}@github.com/{git_user}/{repo_name}.git"
# !git clone "https://github.com/diarrabell/space-images.git"
# Out:
# enter git token··········
# Cloning into 'space-images'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (138/138), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 138 (delta 64), reused 99 (delta 34), pack-reused 0
# Receiving objects: 100% (138/138), 40.10 MiB | 34.88 MiB/s, done.
# Resolving deltas: 100% (64/64), done.

# %%
# access training data from google drive
# !pip install PyDrive
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# !gdown 10C-0jNSiH-dGXnQ8XqIBH2I1VvIOd_sZ

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
download = drive.CreateFile({'id': '10C-0jNSiH-dGXnQ8XqIBH2I1VvIOd_sZ'})
download.GetContentFile('images.zip')

# %%
# extract data from zip file
# !unzip /content/images.zip

# %%
# move training data to data folder
! mv '/content/images' '/content/space-images/data/raw'

# %% [markdown]
# # Execute scripts

# %%
# %run /content/space-images/scripts/setup.py
# Out:
# ------------------------
# Creating Dataloaders...
# ['.config', '__MACOSX', 'space-images', 'images.zip']
# Classes: ['fake', 'real']
# ------------------------
# Plotting batch of images...
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# ------------------------
# Training model...
# Epoch 0/11
# ----------
# train Loss: 0.5472 Acc: 0.7234
# val Loss: 0.2197 Acc: 0.9592
#
# Epoch 1/11
# ----------
# train Loss: 0.3805 Acc: 0.8298
# val Loss: 0.5548 Acc: 0.6735
#
# Epoch 2/11
# ----------
# train Loss: 0.4245 Acc: 0.8032
# val Loss: 0.2383 Acc: 0.8980
#
# Epoch 3/11
# ----------
# train Loss: 0.4603 Acc: 0.7979
# val Loss: 0.3898 Acc: 0.8776
#
# Epoch 4/11
# ----------
# train Loss: 0.4561 Acc: 0.7979
# val Loss: 0.2752 Acc: 0.8776
#
# Epoch 5/11
# ----------
# train Loss: 0.4302 Acc: 0.8191
# val Loss: 0.1187 Acc: 0.9592
#
# Epoch 6/11
# ----------
# ...
